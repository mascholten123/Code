# %% [markdown]
# # Solar Sizing for 3 ha

# %% [markdown]
# ## Direct drive

# %%
#Imports 
import pvlib
from pvlib.location import Location
from pvlib import pvsystem, location, modelchain, iotools
from pvlib.temperature import TEMPERATURE_MODEL_PARAMETERS
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import pathlib
from datetime import datetime
from dataclasses import dataclass
import sqlite3
import scipy

# %%
#Worst day from PlantWaterCalcs.ipynb
Q_max = 62.2512 #m3/day for 3ha
day_max = pd.to_datetime('2020-06-11').date()
max_flow_rate = (2*50*100) /(1000*3600) #m3/s
time_min = (Q_max) / (max_flow_rate* 3600) #hours


#Pump P vs Q equation from PumpCurve.ipynb --> P = a*Q^3 + b*Q^2 + c*Q + c
a = 445687894.591783
b = -984696.5871017637
c = 854.0710206707552
d = -0.05692714507987253

max_power = a*(max_flow_rate**3) + b*(max_flow_rate**2) + c*max_flow_rate + d #kw

# %%
def root_pump_curve(a,b,c,d,P,Q):
    '''function Return zero in terms of Q of pump power equation given a,b,c,d and P'''
    return (a*(Q**3) + b*(Q**2) + c*Q + d - P)

# %%
#Import and clean Solar data 
con = sqlite3.connect("../NetworkCode/SolarData.sqlite")
df_weather_CEBIVE_raw = pd.read_sql_query("SELECT * from cebiveSolarDailyHourly", con)
con.close()

#Convert date to datetime
df_weather_CEBIVE_raw['iso_date'] = pd.to_datetime(df_weather_CEBIVE_raw['iso_date'])
df_weather_CEBIVE_raw.index = pd.to_datetime(df_weather_CEBIVE_raw['iso_date'])

#Only data where location is CEBIVE and date is day_max
df_weather = df_weather_CEBIVE_raw[(df_weather_CEBIVE_raw['location'] == 'CEBIVE') & (df_weather_CEBIVE_raw['iso_date'].dt.date == day_max)]

#Formatting data to input into pvlib model
weather = pd.DataFrame({
    'ghi': df_weather['Cloudy_sky.ghi'], 'dhi': df_weather['Cloudy_sky.dhi'], 'dni': df_weather['Cloudy_sky.dni'],
    'temp_air':  df_weather['Temp'], 'wind_speed':  df_weather['wind_speed'], 
})

loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE

# %%
# weather data
df_daily_irrigation =  pd.read_pickle('../NetworkCode/df_areas.pkl') #daily irrigation need in m3/day for 1h, 2ha and 3ha 
df_daily_irrigation['1ha_hrs'] = df_daily_irrigation['1 ha'] / (max_flow_rate* 3600) # convert to hrs
df_daily_irrigation['2ha_hrs'] = df_daily_irrigation['2 ha'] / (max_flow_rate* 3600) 
df_daily_irrigation['3ha_hrs'] = df_daily_irrigation['3 ha'] / (max_flow_rate* 3600) 
df_daily_irrigation.index = pd.to_datetime(df_daily_irrigation.index)


#create full weather data set
df_weather_full = df_weather_CEBIVE_raw[(df_weather_CEBIVE_raw['location'] == 'CEBIVE')]
df_weather_full.index = pd.to_datetime(df_weather_full['iso_date'])
weather_full = pd.DataFrame({
    'ghi': df_weather_full['Cloudy_sky.ghi'], 'dhi': df_weather_full['Cloudy_sky.dhi'], 'dni': df_weather_full['Cloudy_sky.dni'],
    'temp_air':  df_weather_full['Temp'], 'wind_speed':  df_weather_full['wind_speed'], 
})

# %%
## Increase number of panels until sufficient amount to cover all historical days with variable speed operation
flag = 0 # flag == 0 --> insufficient number of panels, flag == 1 --> sufficient number of panels found 
n_panels = 1 # number of panels to use

while flag == 0: 

    #Calculate solar panel power production for all days with n panels
    loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE
    solpos = loc.get_solarposition(weather_full.index)
    module_parameters = {'pdc0': 0.35, 'gamma_pdc': -0.004, 'b': 0.05} #350W pannel 
    temp_params = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']

    array_full = pvsystem.Array(mount=pvsystem.FixedMount(20, 180),
                        module_parameters=module_parameters,
                        temperature_model_parameters=temp_params, modules_per_string=n_panels)
    system_full = pvsystem.PVSystem(arrays=[array_full], inverter_parameters={'pdc0': 5, 'eta_inv_nom':0.95, 'strings_per_inverter':1 })
    mc_full = modelchain.ModelChain(system_full, loc, spectral_model='no_loss')
    _ = mc_full.run_model(weather_full)

    df_solar_full = pd.DataFrame({'solar_power': mc_full.results.ac})

    #Calculate the flow rate [m3/s] for each hour for variable speed pump 
    df_solar_full['flow_rate'] = 0 #initialize column
    # Iterate over the index of df_solar_full directly
    for hour in df_solar_full.index:
        if df_solar_full.loc[hour, 'solar_power'] >= max_power:
            df_solar_full.loc[hour, 'flow_rate'] = max_flow_rate
        elif df_solar_full.loc[hour, 'solar_power'] == 0:
            #Handle the case when solar power is zero 
            df_solar_full.loc[hour, 'flow_rate'] = 0
        else:
            # Use root_scalar to find the root of the pump curve equation
            solution = scipy.optimize.root_scalar(lambda x: root_pump_curve(a, b, c, d, df_solar_full.loc[hour, 'solar_power'], x), x0=max_flow_rate)
            df_solar_full.loc[hour, 'flow_rate'] = solution.root

    # SAFETY: Check for negative flow rates
    negative_flow_rates = df_solar_full[df_solar_full['flow_rate'] < 0]
    if not negative_flow_rates.empty:
        raise ValueError(f"Negative flow rates found in hours: {negative_flow_rates.index.tolist()}")


    # Assuming constant flow rate over each hour, calculate the total daily pumpible water 
    df_solar_full['flow_rate_hourly']= df_solar_full['flow_rate'] * 3600
    df_daily_irrigation['3ha variable speed'] =  df_solar_full['flow_rate_hourly'].resample('D').sum()

    #Is the possible irrigaiation with variable speed operation sufficient  with n_panels? 
    day_flag = 0 # flag == 0 --> insufficient number of panels, flag == 1 --> sufficient number of panels found
    for day in df_daily_irrigation.index:
        if df_daily_irrigation['3 ha'].loc[day] > df_daily_irrigation['3ha variable speed'].loc[day]:
            print(f'{n_panels} panel(s) is not sufficient with variable speed operation, on {day} the irrigation deficit is {df_daily_irrigation["3 ha"].loc[day] - df_daily_irrigation["3ha variable speed"].loc[day]} m3')
            day_flag = 1
        
    if day_flag == 1:
        n_panels += 1
    else:
        flag = 1
        print(f'{n_panels} panel(s) is sufficient with variable speed operation')

    if n_panels > 20: #safety check
        raise ValueError('the number of PV panels required is greater than 10')         


#Takes a bit over 4 mins to run
# Out:
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00015324026077589696' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-01 00:00:00 the irrigation deficit is 21.999864047652085 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-02 00:00:00 the irrigation deficit is 25.725457887363607 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-03 00:00:00 the irrigation deficit is 16.22822192986626 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-04 00:00:00 the irrigation deficit is 18.021253702983465 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-05 00:00:00 the irrigation deficit is 20.610209375123734 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-06 00:00:00 the irrigation deficit is 16.863859984713653 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-07 00:00:00 the irrigation deficit is 16.868061928273868 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-08 00:00:00 the irrigation deficit is 22.730247735719157 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-09 00:00:00 the irrigation deficit is 21.4240398072091 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-10 00:00:00 the irrigation deficit is 20.312983222637225 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-11 00:00:00 the irrigation deficit is 17.651864628040826 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-12 00:00:00 the irrigation deficit is 14.464832083613658 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-13 00:00:00 the irrigation deficit is 17.331841540607364 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-14 00:00:00 the irrigation deficit is 17.18581319731195 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-15 00:00:00 the irrigation deficit is 16.857352204275724 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-16 00:00:00 the irrigation deficit is 15.10430297282941 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-17 00:00:00 the irrigation deficit is 12.640683724260704 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-18 00:00:00 the irrigation deficit is 21.131879552960136 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-19 00:00:00 the irrigation deficit is 19.328171595346987 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-20 00:00:00 the irrigation deficit is 19.65985370339805 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-21 00:00:00 the irrigation deficit is 18.74080308834589 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-22 00:00:00 the irrigation deficit is 17.142226258815207 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-23 00:00:00 the irrigation deficit is 23.526494374079206 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-24 00:00:00 the irrigation deficit is 24.232717567987457 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-25 00:00:00 the irrigation deficit is 25.553540867207538 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-26 00:00:00 the irrigation deficit is 23.97835631458306 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-27 00:00:00 the irrigation deficit is 24.33712203442823 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-28 00:00:00 the irrigation deficit is 26.18021195678707 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-29 00:00:00 the irrigation deficit is 25.383201453227546 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-30 00:00:00 the irrigation deficit is 24.364453795768263 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-31 00:00:00 the irrigation deficit is 23.290621167628316 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-01 00:00:00 the irrigation deficit is 25.099827996202556 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-02 00:00:00 the irrigation deficit is 19.284052749816226 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-03 00:00:00 the irrigation deficit is 25.765937469899573 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-04 00:00:00 the irrigation deficit is 25.030733520143063 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-05 00:00:00 the irrigation deficit is 17.873011615221024 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-06 00:00:00 the irrigation deficit is 17.087311127860996 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-07 00:00:00 the irrigation deficit is 25.08671838580715 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-08 00:00:00 the irrigation deficit is 20.949710496102867 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-09 00:00:00 the irrigation deficit is 24.087576593073354 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-10 00:00:00 the irrigation deficit is 29.128678209321745 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-11 00:00:00 the irrigation deficit is 30.983829644029274 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-12 00:00:00 the irrigation deficit is 19.995988923724042 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-13 00:00:00 the irrigation deficit is 23.218592452377315 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-14 00:00:00 the irrigation deficit is 26.811799487189273 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-15 00:00:00 the irrigation deficit is 24.605670546227195 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-16 00:00:00 the irrigation deficit is 21.850103237912574 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-17 00:00:00 the irrigation deficit is 23.72077647398436 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-18 00:00:00 the irrigation deficit is 26.17593131258392 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-19 00:00:00 the irrigation deficit is 27.061508408411786 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-20 00:00:00 the irrigation deficit is 23.935085802633978 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-21 00:00:00 the irrigation deficit is 24.41750033292552 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-22 00:00:00 the irrigation deficit is 27.079694969386864 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-23 00:00:00 the irrigation deficit is 22.848703736242445 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-24 00:00:00 the irrigation deficit is 24.434309356877513 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-25 00:00:00 the irrigation deficit is 21.322450622982508 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-26 00:00:00 the irrigation deficit is 25.462562153025104 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-27 00:00:00 the irrigation deficit is 20.68751072295634 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-28 00:00:00 the irrigation deficit is 24.18071921220453 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-01 00:00:00 the irrigation deficit is 21.53569748205335 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-02 00:00:00 the irrigation deficit is 19.570690181734598 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-03 00:00:00 the irrigation deficit is 26.776066544417986 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-04 00:00:00 the irrigation deficit is 23.005875385733454 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 26.518788485657502 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 26.994182752695593 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-07 00:00:00 the irrigation deficit is 22.06102552340136 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-08 00:00:00 the irrigation deficit is 29.586269535073832 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-09 00:00:00 the irrigation deficit is 30.80765619771709 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-10 00:00:00 the irrigation deficit is 33.39937521405557 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-11 00:00:00 the irrigation deficit is 26.733276255350592 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-12 00:00:00 the irrigation deficit is 20.134244223403527 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-13 00:00:00 the irrigation deficit is 21.548767919803844 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-14 00:00:00 the irrigation deficit is 28.883411661966655 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-15 00:00:00 the irrigation deficit is 26.92924283006087 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-16 00:00:00 the irrigation deficit is 24.709144326892773 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-17 00:00:00 the irrigation deficit is 24.364209804218515 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-18 00:00:00 the irrigation deficit is 25.490606133788148 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-19 00:00:00 the irrigation deficit is 28.748099891744566 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-20 00:00:00 the irrigation deficit is 26.763925157389913 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-21 00:00:00 the irrigation deficit is 25.07886405772282 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-22 00:00:00 the irrigation deficit is 24.39378844306472 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-23 00:00:00 the irrigation deficit is 32.59074840214847 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-24 00:00:00 the irrigation deficit is 28.802427039912857 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-25 00:00:00 the irrigation deficit is 29.77122188895344 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-26 00:00:00 the irrigation deficit is 26.060014327808428 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-27 00:00:00 the irrigation deficit is 29.251095108998896 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-28 00:00:00 the irrigation deficit is 33.553968648287594 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-29 00:00:00 the irrigation deficit is 26.671851952641255 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-30 00:00:00 the irrigation deficit is 30.993662855478036 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-31 00:00:00 the irrigation deficit is 31.61239232209792 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-01 00:00:00 the irrigation deficit is 29.45454627820449 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-02 00:00:00 the irrigation deficit is 32.510778676364836 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-03 00:00:00 the irrigation deficit is 35.57378341058184 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-04 00:00:00 the irrigation deficit is 35.59177505495622 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-05 00:00:00 the irrigation deficit is 37.0513487992053 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-06 00:00:00 the irrigation deficit is 30.248295930208958 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-07 00:00:00 the irrigation deficit is 34.71381926308885 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-08 00:00:00 the irrigation deficit is 31.590462429714385 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-09 00:00:00 the irrigation deficit is 26.812363915182672 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-10 00:00:00 the irrigation deficit is 27.41908516103714 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-11 00:00:00 the irrigation deficit is 28.88427432011587 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-12 00:00:00 the irrigation deficit is 22.97016431978346 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-13 00:00:00 the irrigation deficit is 21.441945435683124 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-14 00:00:00 the irrigation deficit is 26.441763289778233 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-15 00:00:00 the irrigation deficit is 28.32910633635983 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-16 00:00:00 the irrigation deficit is 33.001804035260044 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-17 00:00:00 the irrigation deficit is 25.51876528889017 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-18 00:00:00 the irrigation deficit is 22.242038971237786 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-19 00:00:00 the irrigation deficit is 18.40650257406839 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-20 00:00:00 the irrigation deficit is 29.011443884083043 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-21 00:00:00 the irrigation deficit is 30.784799105310597 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-22 00:00:00 the irrigation deficit is 28.572198286920276 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-23 00:00:00 the irrigation deficit is 30.18536560839353 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-24 00:00:00 the irrigation deficit is 32.81987904598809 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-25 00:00:00 the irrigation deficit is 28.035330664597858 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-26 00:00:00 the irrigation deficit is 22.565425254244516 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-27 00:00:00 the irrigation deficit is 28.839027485291425 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-28 00:00:00 the irrigation deficit is 30.150460017899746 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-29 00:00:00 the irrigation deficit is 30.884477922850003 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-30 00:00:00 the irrigation deficit is 34.66595690277046 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-01 00:00:00 the irrigation deficit is 32.23628611687072 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-02 00:00:00 the irrigation deficit is 30.813394064375828 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-03 00:00:00 the irrigation deficit is 35.942593194349534 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-04 00:00:00 the irrigation deficit is 21.613267971616065 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-05 00:00:00 the irrigation deficit is 30.144956277603704 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-06 00:00:00 the irrigation deficit is 37.292469984586035 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-07 00:00:00 the irrigation deficit is 38.888185712254064 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-08 00:00:00 the irrigation deficit is 32.056866282232676 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-09 00:00:00 the irrigation deficit is 28.696799067791105 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-10 00:00:00 the irrigation deficit is 22.512492063352525 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-11 00:00:00 the irrigation deficit is 30.051556139031273 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-12 00:00:00 the irrigation deficit is 36.59667653054944 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-13 00:00:00 the irrigation deficit is 32.52583748046491 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-14 00:00:00 the irrigation deficit is 28.79852690568637 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-15 00:00:00 the irrigation deficit is 30.279082460853353 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-16 00:00:00 the irrigation deficit is 29.201004323344424 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-17 00:00:00 the irrigation deficit is 29.702767058151068 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-18 00:00:00 the irrigation deficit is 16.090888563091184 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-19 00:00:00 the irrigation deficit is 18.51335128092449 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-20 00:00:00 the irrigation deficit is 21.65322626024807 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-21 00:00:00 the irrigation deficit is 22.85345427717212 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-22 00:00:00 the irrigation deficit is 26.209834520905545 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-23 00:00:00 the irrigation deficit is 12.251388397832477 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-24 00:00:00 the irrigation deficit is 25.04453389798106 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-25 00:00:00 the irrigation deficit is 15.657489231499545 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-26 00:00:00 the irrigation deficit is 15.447862166345574 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-27 00:00:00 the irrigation deficit is 23.17179461899746 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-28 00:00:00 the irrigation deficit is 22.575799390959183 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-29 00:00:00 the irrigation deficit is 25.708912004218448 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-30 00:00:00 the irrigation deficit is 24.399350973310693 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-31 00:00:00 the irrigation deficit is 16.71485352725329 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-01 00:00:00 the irrigation deficit is 21.734156578101448 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-02 00:00:00 the irrigation deficit is 20.1141508566323 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-03 00:00:00 the irrigation deficit is 13.847821874114251 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-04 00:00:00 the irrigation deficit is 17.572372177192324 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-05 00:00:00 the irrigation deficit is 22.436726620999224 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-06 00:00:00 the irrigation deficit is 17.007507398767675 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-07 00:00:00 the irrigation deficit is 24.96789744054895 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-08 00:00:00 the irrigation deficit is 18.29419483250784 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-09 00:00:00 the irrigation deficit is 17.051315232828323 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-10 00:00:00 the irrigation deficit is 22.56911184327496 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-11 00:00:00 the irrigation deficit is 24.6265686234158 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-12 00:00:00 the irrigation deficit is 26.19264867958808 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-13 00:00:00 the irrigation deficit is 23.741516303709222 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-14 00:00:00 the irrigation deficit is 31.329878216338066 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-15 00:00:00 the irrigation deficit is 22.55672885363206 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-16 00:00:00 the irrigation deficit is 27.024562311803535 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-17 00:00:00 the irrigation deficit is 22.91618561341484 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-18 00:00:00 the irrigation deficit is 31.519906081486987 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-19 00:00:00 the irrigation deficit is 19.217037521923324 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-20 00:00:00 the irrigation deficit is 15.04208154933275 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-21 00:00:00 the irrigation deficit is 19.405220630567406 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-22 00:00:00 the irrigation deficit is 12.834111142938767 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-23 00:00:00 the irrigation deficit is 7.350962153393979 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-24 00:00:00 the irrigation deficit is 2.66776949827244 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-25 00:00:00 the irrigation deficit is 14.485428027840287 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-26 00:00:00 the irrigation deficit is 11.848584169367236 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-27 00:00:00 the irrigation deficit is 17.738703762527933 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-28 00:00:00 the irrigation deficit is 11.674931407229604 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-29 00:00:00 the irrigation deficit is 13.504414819588924 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-30 00:00:00 the irrigation deficit is 9.265660713311734 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-01 00:00:00 the irrigation deficit is 9.722087268861166 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-02 00:00:00 the irrigation deficit is 12.531984345641604 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-03 00:00:00 the irrigation deficit is 12.700868170384409 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-04 00:00:00 the irrigation deficit is 13.627731702112843 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-05 00:00:00 the irrigation deficit is 17.88706150947361 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-06 00:00:00 the irrigation deficit is 8.856390620331753 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-07 00:00:00 the irrigation deficit is 18.00095902069925 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-08 00:00:00 the irrigation deficit is 14.106569715588702 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-09 00:00:00 the irrigation deficit is 16.520034012528598 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-10 00:00:00 the irrigation deficit is 21.45961731347259 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-11 00:00:00 the irrigation deficit is 12.754319933758616 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-12 00:00:00 the irrigation deficit is 14.600114549415915 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-13 00:00:00 the irrigation deficit is 17.007626684311486 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-14 00:00:00 the irrigation deficit is 8.71123034297124 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-15 00:00:00 the irrigation deficit is 13.713634327353818 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-16 00:00:00 the irrigation deficit is 12.633759653884189 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-17 00:00:00 the irrigation deficit is 13.974089550500036 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-18 00:00:00 the irrigation deficit is 17.217512193992363 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-19 00:00:00 the irrigation deficit is 9.304871996931194 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-20 00:00:00 the irrigation deficit is 9.792330295769442 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-21 00:00:00 the irrigation deficit is 12.12576692575057 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-22 00:00:00 the irrigation deficit is 7.991449611583901 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-23 00:00:00 the irrigation deficit is 8.305061079201483 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-24 00:00:00 the irrigation deficit is 17.272668019254976 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-25 00:00:00 the irrigation deficit is 17.965059851168583 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-26 00:00:00 the irrigation deficit is 18.03225347612287 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-27 00:00:00 the irrigation deficit is 19.156621463062507 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-28 00:00:00 the irrigation deficit is 17.849170296387985 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-29 00:00:00 the irrigation deficit is 17.048708716030696 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-30 00:00:00 the irrigation deficit is 16.05838515537212 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-31 00:00:00 the irrigation deficit is 11.43910403930969 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-01 00:00:00 the irrigation deficit is 18.902931954356735 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-02 00:00:00 the irrigation deficit is 21.550738932163803 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-03 00:00:00 the irrigation deficit is 24.359667040426473 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-04 00:00:00 the irrigation deficit is 14.780747842641773 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-05 00:00:00 the irrigation deficit is 23.553967846153572 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-06 00:00:00 the irrigation deficit is 23.950808024948735 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-07 00:00:00 the irrigation deficit is 21.066960509981914 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-08 00:00:00 the irrigation deficit is 22.53625161739732 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-09 00:00:00 the irrigation deficit is 19.48207020733341 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-10 00:00:00 the irrigation deficit is 13.717235607321532 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-11 00:00:00 the irrigation deficit is 16.234750523853094 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-12 00:00:00 the irrigation deficit is 13.965013089015828 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-13 00:00:00 the irrigation deficit is 18.635883858559524 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-14 00:00:00 the irrigation deficit is 13.23957857997446 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-15 00:00:00 the irrigation deficit is 21.593446500999764 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-16 00:00:00 the irrigation deficit is 22.959165873445436 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-17 00:00:00 the irrigation deficit is 10.958855455114087 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-18 00:00:00 the irrigation deficit is 15.350497549588553 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-19 00:00:00 the irrigation deficit is 16.268032313688675 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-20 00:00:00 the irrigation deficit is 23.14069947744423 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-21 00:00:00 the irrigation deficit is 23.311713006807796 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-22 00:00:00 the irrigation deficit is 25.26088362249679 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-23 00:00:00 the irrigation deficit is 10.700696373986366 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-24 00:00:00 the irrigation deficit is 16.976634653206702 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-25 00:00:00 the irrigation deficit is 21.47242838754409 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-26 00:00:00 the irrigation deficit is 22.915858829044403 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-27 00:00:00 the irrigation deficit is 19.875239016042222 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-28 00:00:00 the irrigation deficit is 25.410909133887117 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-29 00:00:00 the irrigation deficit is 25.4486920721205 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-30 00:00:00 the irrigation deficit is 27.666068733234496 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-31 00:00:00 the irrigation deficit is 32.201694303972715 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-01 00:00:00 the irrigation deficit is 20.675149753499046 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-02 00:00:00 the irrigation deficit is 19.3192974088529 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-03 00:00:00 the irrigation deficit is 16.570883776035167 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-04 00:00:00 the irrigation deficit is 26.1891651805322 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-05 00:00:00 the irrigation deficit is 14.260082322859386 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-06 00:00:00 the irrigation deficit is 27.67612014859816 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-07 00:00:00 the irrigation deficit is 25.9813517013038 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-08 00:00:00 the irrigation deficit is 12.539081103495704 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-09 00:00:00 the irrigation deficit is 20.18082713811698 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-10 00:00:00 the irrigation deficit is 25.0875120577335 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-11 00:00:00 the irrigation deficit is 22.26925085643886 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-12 00:00:00 the irrigation deficit is 13.455520560763942 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-13 00:00:00 the irrigation deficit is 17.402598997049026 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-14 00:00:00 the irrigation deficit is 27.059312830136825 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-15 00:00:00 the irrigation deficit is 27.107395221555244 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-16 00:00:00 the irrigation deficit is 29.53065583298892 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-17 00:00:00 the irrigation deficit is 27.63593103835572 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-18 00:00:00 the irrigation deficit is 26.51561615456665 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-19 00:00:00 the irrigation deficit is 12.692298425203111 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-20 00:00:00 the irrigation deficit is 27.855154916712685 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-21 00:00:00 the irrigation deficit is 20.241679703641566 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-22 00:00:00 the irrigation deficit is 23.411350231056087 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-23 00:00:00 the irrigation deficit is 33.02490236808448 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-24 00:00:00 the irrigation deficit is 14.99618444883437 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-25 00:00:00 the irrigation deficit is 14.976475245332447 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-26 00:00:00 the irrigation deficit is 22.438281105625087 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-27 00:00:00 the irrigation deficit is 19.08844267559624 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-28 00:00:00 the irrigation deficit is 23.96032787295437 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-29 00:00:00 the irrigation deficit is 17.08232851486409 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-30 00:00:00 the irrigation deficit is 13.380605866874438 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-01 00:00:00 the irrigation deficit is 14.605326010630893 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-02 00:00:00 the irrigation deficit is 18.550903083476914 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-03 00:00:00 the irrigation deficit is 24.379496917572023 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-04 00:00:00 the irrigation deficit is 20.944509110021343 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-05 00:00:00 the irrigation deficit is 17.16302353211843 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-06 00:00:00 the irrigation deficit is 8.438420263078834 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-07 00:00:00 the irrigation deficit is 21.57962261434005 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-08 00:00:00 the irrigation deficit is 16.943009552222712 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-09 00:00:00 the irrigation deficit is 14.201840862911416 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-10 00:00:00 the irrigation deficit is 18.084986680767127 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-11 00:00:00 the irrigation deficit is 23.209063729554764 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-12 00:00:00 the irrigation deficit is 16.424565035708405 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-13 00:00:00 the irrigation deficit is 23.297321875676708 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-14 00:00:00 the irrigation deficit is 22.584682691527277 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-15 00:00:00 the irrigation deficit is 22.199963365006674 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-16 00:00:00 the irrigation deficit is 25.34235405193149 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-17 00:00:00 the irrigation deficit is 29.49665862928695 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-18 00:00:00 the irrigation deficit is 19.887814677642606 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-19 00:00:00 the irrigation deficit is 21.90886245480623 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-20 00:00:00 the irrigation deficit is 20.524576536448762 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-21 00:00:00 the irrigation deficit is 29.024023377382928 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-22 00:00:00 the irrigation deficit is 24.38161099793043 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-23 00:00:00 the irrigation deficit is 26.34187970504886 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-24 00:00:00 the irrigation deficit is 28.767261570145983 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-25 00:00:00 the irrigation deficit is 24.788608696469346 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-26 00:00:00 the irrigation deficit is 27.72687912110123 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-27 00:00:00 the irrigation deficit is 23.875920452633764 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-28 00:00:00 the irrigation deficit is 26.370348280054262 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-29 00:00:00 the irrigation deficit is 22.9699922741944 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-30 00:00:00 the irrigation deficit is 18.542326500342106 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-31 00:00:00 the irrigation deficit is 15.474422382735241 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-01 00:00:00 the irrigation deficit is 25.39587061916893 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-02 00:00:00 the irrigation deficit is 25.76036395909528 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-03 00:00:00 the irrigation deficit is 20.706310994632016 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-04 00:00:00 the irrigation deficit is 13.903565486020455 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-05 00:00:00 the irrigation deficit is 9.153369918963664 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-06 00:00:00 the irrigation deficit is 9.529870575655996 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-07 00:00:00 the irrigation deficit is 16.866179174015823 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-08 00:00:00 the irrigation deficit is 26.56583624416157 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-09 00:00:00 the irrigation deficit is 18.160209177793575 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-10 00:00:00 the irrigation deficit is 17.176958661318498 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-11 00:00:00 the irrigation deficit is 14.946312393813095 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-12 00:00:00 the irrigation deficit is 15.780874384629712 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-13 00:00:00 the irrigation deficit is 20.723984636207746 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-14 00:00:00 the irrigation deficit is 20.08797867985404 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-15 00:00:00 the irrigation deficit is 25.537258882752194 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-16 00:00:00 the irrigation deficit is 23.10293756073493 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-17 00:00:00 the irrigation deficit is 22.95361147577727 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-18 00:00:00 the irrigation deficit is 21.649236721883256 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-19 00:00:00 the irrigation deficit is 20.768843455788378 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-20 00:00:00 the irrigation deficit is 21.811712964837717 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-21 00:00:00 the irrigation deficit is 20.623240834537437 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-22 00:00:00 the irrigation deficit is 19.054860526553142 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-23 00:00:00 the irrigation deficit is 18.747867400616357 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-24 00:00:00 the irrigation deficit is 20.426089788467042 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-25 00:00:00 the irrigation deficit is 25.49566458093404 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-26 00:00:00 the irrigation deficit is 22.448429841112187 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-27 00:00:00 the irrigation deficit is 22.10290654519816 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-28 00:00:00 the irrigation deficit is 20.847467836106727 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-29 00:00:00 the irrigation deficit is 25.812296917013708 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-30 00:00:00 the irrigation deficit is 26.97439602172929 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-01 00:00:00 the irrigation deficit is 20.378985059333726 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-02 00:00:00 the irrigation deficit is 20.693317774325642 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-03 00:00:00 the irrigation deficit is 23.67628143338928 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-04 00:00:00 the irrigation deficit is 20.13179091495205 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-05 00:00:00 the irrigation deficit is 18.89101313453174 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-06 00:00:00 the irrigation deficit is 21.757171017026863 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-07 00:00:00 the irrigation deficit is 23.0154598496476 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-08 00:00:00 the irrigation deficit is 23.349210381272172 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-09 00:00:00 the irrigation deficit is 13.977079610397265 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-10 00:00:00 the irrigation deficit is 16.50573678378971 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-11 00:00:00 the irrigation deficit is 20.59055604762937 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-12 00:00:00 the irrigation deficit is 23.483409561804315 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-13 00:00:00 the irrigation deficit is 20.97414777111584 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-14 00:00:00 the irrigation deficit is 15.644457537596155 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-15 00:00:00 the irrigation deficit is 19.943800514751395 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-16 00:00:00 the irrigation deficit is 20.772496949099022 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-17 00:00:00 the irrigation deficit is 22.060525236480757 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-18 00:00:00 the irrigation deficit is 29.378874725104534 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-19 00:00:00 the irrigation deficit is 18.65357681670521 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-20 00:00:00 the irrigation deficit is 31.814045904885194 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-21 00:00:00 the irrigation deficit is 21.718645382379144 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-22 00:00:00 the irrigation deficit is 24.51799423888458 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-23 00:00:00 the irrigation deficit is 26.11113188622983 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-24 00:00:00 the irrigation deficit is 27.57323716506795 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-25 00:00:00 the irrigation deficit is 20.649659327965338 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-26 00:00:00 the irrigation deficit is 19.01403004514524 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-27 00:00:00 the irrigation deficit is 18.331928838522984 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-28 00:00:00 the irrigation deficit is 16.09703734179682 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-29 00:00:00 the irrigation deficit is 22.308352432500925 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-30 00:00:00 the irrigation deficit is 26.34072558705935 m3
# ...
# 4 panel(s) is not sufficient with variable speed operation, on 2014-04-02 00:00:00 the irrigation deficit is 3.13440706730249 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2014-04-17 00:00:00 the irrigation deficit is 1.2812830832500808 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2014-07-24 00:00:00 the irrigation deficit is 2.384160141886909 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2014-07-25 00:00:00 the irrigation deficit is 1.43706326629043 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-04-03 00:00:00 the irrigation deficit is 6.270933990986251 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-04-05 00:00:00 the irrigation deficit is 2.1591992611439323 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-05-23 00:00:00 the irrigation deficit is 0.2613907003795646 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-06-30 00:00:00 the irrigation deficit is 3.295721603730918 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-07-06 00:00:00 the irrigation deficit is 0.5408429422811736 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-08-05 00:00:00 the irrigation deficit is 3.786802176568031 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-09-11 00:00:00 the irrigation deficit is 2.7162676689466565 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-09-13 00:00:00 the irrigation deficit is 3.557286396007761 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-10-23 00:00:00 the irrigation deficit is 0.935497083774969 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2015-10-24 00:00:00 the irrigation deficit is 0.2069328372629471 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2016-04-14 00:00:00 the irrigation deficit is 0.5998795058805158 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2017-04-24 00:00:00 the irrigation deficit is 7.601608480824742 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2017-09-16 00:00:00 the irrigation deficit is 2.2479146799598233 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2018-07-10 00:00:00 the irrigation deficit is 5.453100935508282 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2018-08-28 00:00:00 the irrigation deficit is 7.263149482773137 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2018-08-29 00:00:00 the irrigation deficit is 1.570894661160139 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2018-10-04 00:00:00 the irrigation deficit is 0.15510054111979343 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2018-10-09 00:00:00 the irrigation deficit is 0.6492204506457249 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2019-03-09 00:00:00 the irrigation deficit is 3.394638390986188 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2019-04-02 00:00:00 the irrigation deficit is 6.102153901733537 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2019-07-31 00:00:00 the irrigation deficit is 0.5414052338689608 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2019-08-22 00:00:00 the irrigation deficit is 2.30343432978664 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2020-06-10 00:00:00 the irrigation deficit is 0.7300684035991338 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2020-06-11 00:00:00 the irrigation deficit is 1.5004735697205973 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2020-07-07 00:00:00 the irrigation deficit is 1.8692052840194862 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2021-04-27 00:00:00 the irrigation deficit is 4.9212584649091795 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2021-05-03 00:00:00 the irrigation deficit is 2.9730327992699657 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2021-05-04 00:00:00 the irrigation deficit is 1.3974772013461276 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2021-07-18 00:00:00 the irrigation deficit is 0.9217367488951922 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 6.853121927683397 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2022-07-03 00:00:00 the irrigation deficit is 1.2500559934266526 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2022-09-02 00:00:00 the irrigation deficit is 0.8573103418517434 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2022-10-25 00:00:00 the irrigation deficit is 9.066684022318448 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-03-09 00:00:00 the irrigation deficit is 2.764797205926399 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-03-10 00:00:00 the irrigation deficit is 1.2090507455841433 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-03-22 00:00:00 the irrigation deficit is 8.583601382073052 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-03-23 00:00:00 the irrigation deficit is 6.644731240693702 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-03-26 00:00:00 the irrigation deficit is 2.9060442978933807 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-04-05 00:00:00 the irrigation deficit is 4.413392303150147 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-04-06 00:00:00 the irrigation deficit is 4.480882227983997 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-05-30 00:00:00 the irrigation deficit is 1.2554109201080088 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-06-23 00:00:00 the irrigation deficit is 10.929679084189146 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-06-27 00:00:00 the irrigation deficit is 0.4645757739989662 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-07-11 00:00:00 the irrigation deficit is 1.7942010914320932 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-07-25 00:00:00 the irrigation deficit is 7.789708822045839 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-07-31 00:00:00 the irrigation deficit is 5.14869360263226 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-02 00:00:00 the irrigation deficit is 2.7836874159281315 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 14.833731682722124 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-15 00:00:00 the irrigation deficit is 0.13532880188952845 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-16 00:00:00 the irrigation deficit is 7.110297318583314 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-20 00:00:00 the irrigation deficit is 2.9925795465373852 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-09-10 00:00:00 the irrigation deficit is 4.5933564682990635 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-09-11 00:00:00 the irrigation deficit is 1.0568212173236944 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-09-26 00:00:00 the irrigation deficit is 4.835851349750925 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-09-27 00:00:00 the irrigation deficit is 3.516539569076656 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-10-02 00:00:00 the irrigation deficit is 1.9272702974648297 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-10-24 00:00:00 the irrigation deficit is 0.17800026400330893 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00010901409975967388' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 5 panel(s) is not sufficient with variable speed operation, on 2010-01-25 00:00:00 the irrigation deficit is 0.08341180127348125 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 15.650186283850045 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 13.134430602949202 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2010-03-10 00:00:00 the irrigation deficit is 0.5107180581137385 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2015-04-03 00:00:00 the irrigation deficit is 0.571219558781884 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2017-04-24 00:00:00 the irrigation deficit is 3.3271561030819505 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2018-07-10 00:00:00 the irrigation deficit is 1.4129310726910838 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2018-08-28 00:00:00 the irrigation deficit is 2.8234300541091173 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 4.737264817403313 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2022-10-25 00:00:00 the irrigation deficit is 3.2717726355179337 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-03-22 00:00:00 the irrigation deficit is 4.092394273659615 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-03-23 00:00:00 the irrigation deficit is 2.3631600708190206 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-04-05 00:00:00 the irrigation deficit is 0.6875799966509462 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-04-06 00:00:00 the irrigation deficit is 0.3458832801067402 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-06-23 00:00:00 the irrigation deficit is 7.022712981681593 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-07-25 00:00:00 the irrigation deficit is 0.3027316069085586 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-07-31 00:00:00 the irrigation deficit is 1.5883212545608885 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 10.864964826624458 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-08-16 00:00:00 the irrigation deficit is 2.347336351991437 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-09-10 00:00:00 the irrigation deficit is 0.23684892732735108 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2023-09-26 00:00:00 the irrigation deficit is 0.8122003534101125 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00012589484538754635' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 6 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 12.822568679742881 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 9.939877185072806 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 2.7721634770862735 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2023-03-22 00:00:00 the irrigation deficit is 0.09824834522457593 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2023-06-23 00:00:00 the irrigation deficit is 3.6212425296797264 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 7.497751182107692 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0001435503135552102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 7 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 10.752287511748548 m3
# 7 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 6.256682020843989 m3
# 7 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 1.095351584717445 m3
# 7 panel(s) is not sufficient with variable speed operation, on 2023-06-23 00:00:00 the irrigation deficit is 0.3624336689593335 m3
# 7 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 4.623646435617012 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00016207043857677006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 8 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 8.73330633195187 m3
# 8 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 2.5799446794368954 m3
# 8 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 1.6225617541894337 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00018156238143232227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 9 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 6.5313059096727955 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00020215524154460087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 10 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 3.9139697836664666 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00022400647626967472' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 11 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 0.9333379939389204 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_32439/3563956519.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0002473108051139422' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 12 panel(s) is sufficient with variable speed operation

# %% [markdown]
# ## Battery configuration

# %%
# Lead acid battery characterisitics 
eta_charge = 0.95
eta_discharge = 0.95
SOC_min = 0.05 #5%
SOC_initial = 0.95 #100%
SOC_max = 0.95 #90%
deprciation = 0.001632 #depreciation per day for 8% per month
capacity = 1 #kWh

# %%
# Find minimum number of batteries required to cover all historical days 1 through 5 PV pannels 

for n_panels_battery in range(1, 13): #number of panels
    n_batteries = 0 #number of batteries in the string 
    flag = 0 #flag == 0 --> insufficient battery capacity found, flag == 1 --> sufficient battery capacity found

    #Calculate solar power output with n_pannels_battery
    loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE
    solpos = loc.get_solarposition(weather_full.index)
    module_parameters = {'pdc0': 0.35, 'gamma_pdc': -0.004, 'b': 0.05} #350W pannel 
    temp_params = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']

    array_full = pvsystem.Array(mount=pvsystem.FixedMount(20, 180),
                        module_parameters=module_parameters,
                        temperature_model_parameters=temp_params, modules_per_string=n_panels_battery)
    system_full = pvsystem.PVSystem(arrays=[array_full], inverter_parameters={'pdc0': 10, 'eta_inv_nom':0.95, 'strings_per_inverter':1 })
    mc_full = modelchain.ModelChain(system_full, loc, spectral_model='no_loss')
    _ = mc_full.run_model(weather_full)
    df_solar_battery = pd.DataFrame({'solar_power': mc_full.results.ac})
    

    #find minimum number of batteries needed to cover all historical days 
    while flag == 0:
        battery_capacity = capacity * n_batteries #kWh
        min_SOC = SOC_min * battery_capacity
        max_SOC = SOC_max * battery_capacity
        E_stored = [battery_capacity] #kWh, battery energy stored over time, initially full 
        day_flag = 0 
        for day, data in df_solar_battery.groupby(df_solar_battery.index.date):
            Q_day = 0 # m3 of water irrigated on day 
            Q_needed = df_daily_irrigation['3 ha'].loc[day.strftime('%Y-%m-%d')] #required irrigation in m3 
            power_day = df_solar_battery['solar_power'].loc[day.strftime('%Y-%m-%d')]
            
            for hour in data.index.hour:
                deficit = Q_needed - Q_day
                power = power_day.iloc[hour] #Power available to pump on that hour

                if deficit > 0: #Need to irrigate more water
                    if (power >= max_power) & (deficit > max_flow_rate * 3600): #Power is greater than max power so irrigate max possinle amount 
                        Q_day += max_flow_rate * 3600
                        E_storable = (power- max_power) * eta_charge #kWh
                    elif (power >= max_power) & (deficit <= max_flow_rate * 3600): #power is greater than max power but dont need to pump max amount
                        P_used = a * (deficit/3600)**3 + b * (deficit/3600)**2 + c * (deficit/3600) + d #power used to pump
                        Q_day += deficit
                        E_storable = (power- P_used) * eta_charge #kWh    
                    elif (power == 0): 
                        E_storable = 0 #no energy stored
                        Q_day += 0
                    elif (power < max_power): #power is less than max power, but still need to pump 
                        Q_possible = scipy.optimize.root_scalar(lambda x: root_pump_curve(a, b, c, d, power, x), x0=max_flow_rate)
                        E_storable = 0 #no energy stored
                        if Q_possible.root*3600 >= deficit:
                            Q_day += deficit
                        else:
                            Q_day += Q_possible.root * 3600
                    

                else: #dont need to irrigate more
                    E_storable =power*eta_charge 

                #Store energy
                if (E_storable + E_stored[-1]*(1-deprciation)) <= max_SOC:
                    E_stored.append(E_stored[-1]*(1-deprciation) + E_storable) #kWh
                else: #if more energy than battery can store, only store what battery can store
                    E_stored.append(max_SOC) #kWh
                
            
                
            if deficit > 0: #still need to irrigate more after all possible pumping hours have been exhausted
                
                #Use energy stored to pump --> Assume always pumping at max flow rate
                time_pump = (deficit / 3600)/ max_flow_rate 
                E_pump = (max_power * time_pump) / eta_discharge

                
                if (E_stored[-1] - E_pump) >= min_SOC: #if enough energy is stored to pump
                    E_stored.append(E_stored[-1]*(1-deprciation) - E_pump)
                else: #if not enough energy is stored to pump
                    #print(f'{n_batteries} batteries is not sufficient with {n_panels_battery} panels, on {day} the energy deficit is {E_pump - (E_stored[-1]- min_SOC)} kWh')
                    day_flag = 1 #flag == 1 --> n_panels_battery is not sufficient with battery operation over historical data

        if day_flag == 1: #after checking all days, if n_batteries is not sufficient with n_panels_battery
            n_batteries+=1
        else: #after checking all days, n_batteries is sufficient with n_panels_battery
            flag = 1 
            print(f'{n_batteries} Lithuim batteries is sufficient with {n_panels_battery} panels over historical data')
                
                    
        if n_batteries > 10: #safety check
            print(f'the required number of batteries is more than 10 for {n_panels_battery} panels')
            flag = 1
            
        
    #Takes 7m 55 with max 10 batteries
    #Takes 13m 4 with max 20 batteries
# Out:
# the required number of batteries is more than 10 for 1 panels
# the required number of batteries is more than 10 for 2 panels
# the required number of batteries is more than 10 for 3 panels
# the required number of batteries is more than 10 for 4 panels
# the required number of batteries is more than 10 for 5 panels
# the required number of batteries is more than 10 for 6 panels
# the required number of batteries is more than 10 for 7 panels
# 10 Lithuim batteries is sufficient with 8 panels over historical data
# 7 Lithuim batteries is sufficient with 9 panels over historical data
# 5 Lithuim batteries is sufficient with 10 panels over historical data
# 3 Lithuim batteries is sufficient with 11 panels over historical data
# 2 Lithuim batteries is sufficient with 12 panels over historical data
