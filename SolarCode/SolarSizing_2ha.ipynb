# %% [markdown]
# # Solar Sizing for 2ha Scenario

# %%
#Imports 
import pvlib
from pvlib.location import Location
from pvlib import pvsystem, location, modelchain, iotools
from pvlib.temperature import TEMPERATURE_MODEL_PARAMETERS
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import pathlib
from datetime import datetime
from dataclasses import dataclass
import sqlite3
import scipy

# %%
#Worst day from PlantWaterCalcs.ipynb
Q_max = 41.5008 #m3/day for 2ha
day_max = pd.to_datetime('2020-06-11').date()
max_flow_rate = (2*50*68) /(1000*3600) #m3/s
time_min = (Q_max) / (max_flow_rate* 3600) #hours


#Pump P vs Q equation from PumpCurve.ipynb --> P = a*Q^3 + b*Q^2 + c*Q + c

a = 457464099.7859799
b = -1002598.6831058152
c = 859.5461108664946
d = -0.054389800267633744

max_power = a*(max_flow_rate**3) + b*(max_flow_rate**2) + c*max_flow_rate + d #kw

# %%
def root_pump_curve(a,b,c,d,P,Q):
    '''function Return zero in terms of Q of pump power equation given a,b,c,d and P'''
    return (a*(Q**3) + b*(Q**2) + c*Q + d - P)

# %%
#Import and clean Solar data 
con = sqlite3.connect("../NetworkCode/SolarData.sqlite")
df_weather_CEBIVE_raw = pd.read_sql_query("SELECT * from cebiveSolarDailyHourly", con)
con.close()

#Convert date to datetime
df_weather_CEBIVE_raw['iso_date'] = pd.to_datetime(df_weather_CEBIVE_raw['iso_date'])
df_weather_CEBIVE_raw.index = pd.to_datetime(df_weather_CEBIVE_raw['iso_date'])

#Only data where location is CEBIVE and date is day_max
df_weather = df_weather_CEBIVE_raw[(df_weather_CEBIVE_raw['location'] == 'CEBIVE') & (df_weather_CEBIVE_raw['iso_date'].dt.date == day_max)]

#Formatting data to input into pvlib model
weather = pd.DataFrame({
    'ghi': df_weather['Cloudy_sky.ghi'], 'dhi': df_weather['Cloudy_sky.dhi'], 'dni': df_weather['Cloudy_sky.dni'],
    'temp_air':  df_weather['Temp'], 'wind_speed':  df_weather['wind_speed'], 
})

loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE

# %%
# weather data
df_daily_irrigation =  pd.read_pickle('../NetworkCode/df_areas.pkl') #daily irrigation need in m3/day for 1h, 2ha and 3ha 
df_daily_irrigation['1ha_hrs'] = df_daily_irrigation['1 ha'] / (max_flow_rate* 3600) # convert to hrs
df_daily_irrigation['2ha_hrs'] = df_daily_irrigation['2 ha'] / (max_flow_rate* 3600) 
df_daily_irrigation['3ha_hrs'] = df_daily_irrigation['3 ha'] / (max_flow_rate* 3600) 
df_daily_irrigation.index = pd.to_datetime(df_daily_irrigation.index)


#create full weather data set
df_weather_full = df_weather_CEBIVE_raw[(df_weather_CEBIVE_raw['location'] == 'CEBIVE')]
df_weather_full.index = pd.to_datetime(df_weather_full['iso_date'])
weather_full = pd.DataFrame({
    'ghi': df_weather_full['Cloudy_sky.ghi'], 'dhi': df_weather_full['Cloudy_sky.dhi'], 'dni': df_weather_full['Cloudy_sky.dni'],
    'temp_air':  df_weather_full['Temp'], 'wind_speed':  df_weather_full['wind_speed'], 
})

# %% [markdown]
# ## Direct drive sizing

# %%
## Increase number of panels until sufficient amount to cover all historical days with variable speed operation
flag = 0 # flag == 0 --> insufficient number of panels, flag == 1 --> sufficient number of panels found 
n_panels = 1 # number of panels to use

while flag == 0: 

    #Calculate solar panel power production for all days with n panels
    loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE
    solpos = loc.get_solarposition(weather_full.index)
    module_parameters = {'pdc0': 0.35, 'gamma_pdc': -0.004, 'b': 0.05} #350W pannel 
    temp_params = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']

    array_full = pvsystem.Array(mount=pvsystem.FixedMount(20, 180),
                        module_parameters=module_parameters,
                        temperature_model_parameters=temp_params, modules_per_string=n_panels)
    system_full = pvsystem.PVSystem(arrays=[array_full], inverter_parameters={'pdc0': 5, 'eta_inv_nom':0.95, 'strings_per_inverter':1 })
    mc_full = modelchain.ModelChain(system_full, loc, spectral_model='no_loss')
    _ = mc_full.run_model(weather_full)

    df_solar_full = pd.DataFrame({'solar_power': mc_full.results.ac})

    #Calculate the flow rate [m3/s] for each hour for variable speed pump 
    df_solar_full['flow_rate'] = 0 #initialize column
    # Iterate over the index of df_solar_full directly
    for hour in df_solar_full.index:
        if df_solar_full.loc[hour, 'solar_power'] >= max_power:
            df_solar_full.loc[hour, 'flow_rate'] = max_flow_rate
        elif df_solar_full.loc[hour, 'solar_power'] == 0:
            #Handle the case when solar power is zero 
            df_solar_full.loc[hour, 'flow_rate'] = 0
        else:
            # Use root_scalar to find the root of the pump curve equation
            solution = scipy.optimize.root_scalar(lambda x: root_pump_curve(a, b, c, d, df_solar_full.loc[hour, 'solar_power'], x), x0=max_flow_rate)
            df_solar_full.loc[hour, 'flow_rate'] = solution.root

    # SAFETY: Check for negative flow rates
    negative_flow_rates = df_solar_full[df_solar_full['flow_rate'] < 0]
    if not negative_flow_rates.empty:
        raise ValueError(f"Negative flow rates found in hours: {negative_flow_rates.index.tolist()}")


    # Assuming constant flow rate over each hour, calculate the total daily pumpible water 
    df_solar_full['flow_rate_hourly']= df_solar_full['flow_rate'] * 3600
    df_daily_irrigation['2ha variable speed'] =  df_solar_full['flow_rate_hourly'].resample('D').sum()

    #Is the possible irrigaiation with variable speed operation sufficient  with n_panels? 
    day_flag = 0 # flag == 0 --> insufficient number of panels, flag == 1 --> sufficient number of panels found
    for day in df_daily_irrigation.index:
        if df_daily_irrigation['2 ha'].loc[day] > df_daily_irrigation['2ha variable speed'].loc[day]:
            print(f'{n_panels} panel(s) is not sufficient with variable speed operation, on {day} the irrigation deficit is {df_daily_irrigation["2 ha"].loc[day] - df_daily_irrigation["2ha variable speed"].loc[day]} m3')
            day_flag = 1
        
    if day_flag == 1:
        n_panels += 1
    else:
        flag = 1
        print(f'{n_panels} panel(s) is sufficient with variable speed operation')

    if n_panels > 10: #safety check
        raise ValueError('the number of PV panels required is greater than 10')         


#Takes a bit over 4 mins to run
# Out:
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00014814576535805346' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-01 00:00:00 the irrigation deficit is 10.109559279126694 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-02 00:00:00 the irrigation deficit is 12.666793605642315 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-03 00:00:00 the irrigation deficit is 9.811158991301046 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-04 00:00:00 the irrigation deficit is 8.695938059510539 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-05 00:00:00 the irrigation deficit is 7.978158360554406 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-06 00:00:00 the irrigation deficit is 4.9292007221235075 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-07 00:00:00 the irrigation deficit is 6.652433845922721 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-08 00:00:00 the irrigation deficit is 13.506156343750277 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-09 00:00:00 the irrigation deficit is 10.777036411509057 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-10 00:00:00 the irrigation deficit is 6.951637932342333 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-11 00:00:00 the irrigation deficit is 10.267486148437175 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-12 00:00:00 the irrigation deficit is 7.1993650948929195 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-13 00:00:00 the irrigation deficit is 8.181674205953101 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-14 00:00:00 the irrigation deficit is 6.334118375008851 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-15 00:00:00 the irrigation deficit is 10.039334380202135 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-16 00:00:00 the irrigation deficit is 5.818911900704181 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-17 00:00:00 the irrigation deficit is 2.8287293037897427 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-18 00:00:00 the irrigation deficit is 8.427514270070397 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-19 00:00:00 the irrigation deficit is 8.470643076333493 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-20 00:00:00 the irrigation deficit is 7.575834818232469 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-21 00:00:00 the irrigation deficit is 6.308651775912136 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-22 00:00:00 the irrigation deficit is 4.467646228082209 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-23 00:00:00 the irrigation deficit is 9.739208720479699 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-24 00:00:00 the irrigation deficit is 10.900567577289266 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-25 00:00:00 the irrigation deficit is 15.240579903417913 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-26 00:00:00 the irrigation deficit is 14.814830755624847 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-27 00:00:00 the irrigation deficit is 12.384144826469928 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-28 00:00:00 the irrigation deficit is 11.632955109683849 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-29 00:00:00 the irrigation deficit is 12.884376384276878 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-30 00:00:00 the irrigation deficit is 11.288633268313868 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-01-31 00:00:00 the irrigation deficit is 10.266280377762442 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-01 00:00:00 the irrigation deficit is 12.854920367749447 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-02 00:00:00 the irrigation deficit is 8.863983680766443 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-03 00:00:00 the irrigation deficit is 13.023096392920545 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-04 00:00:00 the irrigation deficit is 11.175213802553493 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-05 00:00:00 the irrigation deficit is 4.907592800279502 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-06 00:00:00 the irrigation deficit is 4.092726916654765 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-07 00:00:00 the irrigation deficit is 9.955012475934602 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-08 00:00:00 the irrigation deficit is 7.27145388507504 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-09 00:00:00 the irrigation deficit is 9.143282503256106 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-10 00:00:00 the irrigation deficit is 12.51790857652453 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-11 00:00:00 the irrigation deficit is 14.188540403483177 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-12 00:00:00 the irrigation deficit is 6.183705122425312 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-13 00:00:00 the irrigation deficit is 9.029078575084675 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-14 00:00:00 the irrigation deficit is 11.154077688631983 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-15 00:00:00 the irrigation deficit is 12.321846320230655 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-16 00:00:00 the irrigation deficit is 8.697554298099938 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-17 00:00:00 the irrigation deficit is 8.990692523508741 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-18 00:00:00 the irrigation deficit is 13.760996244396752 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-19 00:00:00 the irrigation deficit is 13.777976694141234 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-20 00:00:00 the irrigation deficit is 9.835408709166828 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-21 00:00:00 the irrigation deficit is 13.4945393624985 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-22 00:00:00 the irrigation deficit is 14.64895299005869 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-23 00:00:00 the irrigation deficit is 8.90080693529088 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-24 00:00:00 the irrigation deficit is 10.699983530945605 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-25 00:00:00 the irrigation deficit is 8.580455679330608 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-26 00:00:00 the irrigation deficit is 13.020850733562598 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-27 00:00:00 the irrigation deficit is 9.102053179178123 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-02-28 00:00:00 the irrigation deficit is 9.721511466720173 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-01 00:00:00 the irrigation deficit is 9.358031510092465 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-02 00:00:00 the irrigation deficit is 7.242592083106686 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-03 00:00:00 the irrigation deficit is 12.96269427042293 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-04 00:00:00 the irrigation deficit is 12.960403687717132 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 17.443070505874076 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 17.553459098382014 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-07 00:00:00 the irrigation deficit is 12.563284138875265 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-08 00:00:00 the irrigation deficit is 11.994009610544765 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-09 00:00:00 the irrigation deficit is 14.02050241855083 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-10 00:00:00 the irrigation deficit is 17.029523505209056 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-11 00:00:00 the irrigation deficit is 12.777808854365059 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-12 00:00:00 the irrigation deficit is 8.134266455889566 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-13 00:00:00 the irrigation deficit is 7.642712810254487 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-14 00:00:00 the irrigation deficit is 14.98253798633273 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-15 00:00:00 the irrigation deficit is 11.296020159022792 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-16 00:00:00 the irrigation deficit is 9.708504244701068 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-17 00:00:00 the irrigation deficit is 10.443211423194683 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-18 00:00:00 the irrigation deficit is 13.2675848871344 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-19 00:00:00 the irrigation deficit is 15.98343112600671 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-20 00:00:00 the irrigation deficit is 11.238016971644324 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-21 00:00:00 the irrigation deficit is 9.428046225834926 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-22 00:00:00 the irrigation deficit is 8.789697199596844 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-23 00:00:00 the irrigation deficit is 15.631027554519541 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-24 00:00:00 the irrigation deficit is 12.86322418701695 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-25 00:00:00 the irrigation deficit is 12.610592923065973 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-26 00:00:00 the irrigation deficit is 10.091825606855803 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-27 00:00:00 the irrigation deficit is 12.142945213912832 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-28 00:00:00 the irrigation deficit is 15.259399779122084 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-29 00:00:00 the irrigation deficit is 10.567515879425994 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-30 00:00:00 the irrigation deficit is 13.939807597392797 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-03-31 00:00:00 the irrigation deficit is 14.028918133358772 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-01 00:00:00 the irrigation deficit is 15.636168817257492 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-02 00:00:00 the irrigation deficit is 16.133825209782458 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-03 00:00:00 the irrigation deficit is 16.248685245148508 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-04 00:00:00 the irrigation deficit is 16.26370583242233 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-05 00:00:00 the irrigation deficit is 19.368564571677666 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-06 00:00:00 the irrigation deficit is 15.306191658865044 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-07 00:00:00 the irrigation deficit is 18.60916711077287 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-08 00:00:00 the irrigation deficit is 16.85448702674125 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-09 00:00:00 the irrigation deficit is 11.743146449986035 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-10 00:00:00 the irrigation deficit is 16.752734336829743 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-11 00:00:00 the irrigation deficit is 16.312632125116355 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-12 00:00:00 the irrigation deficit is 10.603821064336234 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-13 00:00:00 the irrigation deficit is 9.248427452283453 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-14 00:00:00 the irrigation deficit is 12.077844777719069 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-15 00:00:00 the irrigation deficit is 15.107956744551524 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-16 00:00:00 the irrigation deficit is 18.358378405077815 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-17 00:00:00 the irrigation deficit is 13.343840485661635 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-18 00:00:00 the irrigation deficit is 12.58241689545412 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-19 00:00:00 the irrigation deficit is 7.59183637432467 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-20 00:00:00 the irrigation deficit is 16.181072346765642 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-21 00:00:00 the irrigation deficit is 15.901302326525645 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-22 00:00:00 the irrigation deficit is 15.047179121633164 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-23 00:00:00 the irrigation deficit is 14.538162595121513 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-24 00:00:00 the irrigation deficit is 16.690259109839232 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-25 00:00:00 the irrigation deficit is 12.093107038605648 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-26 00:00:00 the irrigation deficit is 12.433705797609772 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-27 00:00:00 the irrigation deficit is 13.738675362473547 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-28 00:00:00 the irrigation deficit is 13.564434240331451 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-29 00:00:00 the irrigation deficit is 14.139636461439615 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-04-30 00:00:00 the irrigation deficit is 17.619200915992444 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-01 00:00:00 the irrigation deficit is 15.531561660800072 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-02 00:00:00 the irrigation deficit is 17.585464284708557 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-03 00:00:00 the irrigation deficit is 20.35047538706551 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-04 00:00:00 the irrigation deficit is 9.113387846119178 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-05 00:00:00 the irrigation deficit is 13.95586658894059 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-06 00:00:00 the irrigation deficit is 17.944896906859313 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-07 00:00:00 the irrigation deficit is 19.265210998074433 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-08 00:00:00 the irrigation deficit is 16.145037927635656 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-09 00:00:00 the irrigation deficit is 13.95116790813585 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-10 00:00:00 the irrigation deficit is 10.857411797113985 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-11 00:00:00 the irrigation deficit is 15.061716454734654 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-12 00:00:00 the irrigation deficit is 19.35094368577432 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-13 00:00:00 the irrigation deficit is 17.73608826685641 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-14 00:00:00 the irrigation deficit is 16.01299454392376 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-15 00:00:00 the irrigation deficit is 16.934591776467116 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-16 00:00:00 the irrigation deficit is 14.237726372346717 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-17 00:00:00 the irrigation deficit is 13.641354027001313 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-18 00:00:00 the irrigation deficit is 7.89778044352472 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-19 00:00:00 the irrigation deficit is 8.787707451005753 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-20 00:00:00 the irrigation deficit is 8.48960649713609 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-21 00:00:00 the irrigation deficit is 10.573315368092906 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-22 00:00:00 the irrigation deficit is 13.667248717196685 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-23 00:00:00 the irrigation deficit is 5.102400824407299 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-24 00:00:00 the irrigation deficit is 13.843922554692782 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-25 00:00:00 the irrigation deficit is 7.713585352765964 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-26 00:00:00 the irrigation deficit is 8.802880360534807 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-27 00:00:00 the irrigation deficit is 11.06741646909633 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-28 00:00:00 the irrigation deficit is 12.143559159087038 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-29 00:00:00 the irrigation deficit is 14.219850622613341 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-30 00:00:00 the irrigation deficit is 11.752569280630931 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-05-31 00:00:00 the irrigation deficit is 7.167397146253041 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-01 00:00:00 the irrigation deficit is 12.20070878597059 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-02 00:00:00 the irrigation deficit is 9.519052560542171 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-03 00:00:00 the irrigation deficit is 6.226812438383128 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-04 00:00:00 the irrigation deficit is 6.335710560125495 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-05 00:00:00 the irrigation deficit is 10.023834755959088 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-06 00:00:00 the irrigation deficit is 6.277042171955696 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-07 00:00:00 the irrigation deficit is 10.942481366389778 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-08 00:00:00 the irrigation deficit is 9.47944690757853 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-09 00:00:00 the irrigation deficit is 5.928537988303617 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-10 00:00:00 the irrigation deficit is 9.773936240925288 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-11 00:00:00 the irrigation deficit is 11.380846689948726 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-12 00:00:00 the irrigation deficit is 11.958166304276464 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-13 00:00:00 the irrigation deficit is 12.319937270285779 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-14 00:00:00 the irrigation deficit is 16.31132541947774 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-15 00:00:00 the irrigation deficit is 11.993071077061463 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-16 00:00:00 the irrigation deficit is 14.693750058118587 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-17 00:00:00 the irrigation deficit is 10.691496121895401 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-18 00:00:00 the irrigation deficit is 16.390820628595158 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-19 00:00:00 the irrigation deficit is 9.823620179688108 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-20 00:00:00 the irrigation deficit is 7.61119984309693 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-21 00:00:00 the irrigation deficit is 10.965079039922184 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-22 00:00:00 the irrigation deficit is 7.110224415173086 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-23 00:00:00 the irrigation deficit is 3.5509558182598937 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-25 00:00:00 the irrigation deficit is 6.961526827782228 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-26 00:00:00 the irrigation deficit is 3.5467645557487906 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-27 00:00:00 the irrigation deficit is 9.209740385583451 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-28 00:00:00 the irrigation deficit is 2.5370305225084877 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-29 00:00:00 the irrigation deficit is 4.438247025914267 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-06-30 00:00:00 the irrigation deficit is 2.494331388038667 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-01 00:00:00 the irrigation deficit is 2.457689975024545 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-02 00:00:00 the irrigation deficit is 3.1802885821718903 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-03 00:00:00 the irrigation deficit is 3.61056944985204 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-04 00:00:00 the irrigation deficit is 4.179737614036849 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-05 00:00:00 the irrigation deficit is 6.48886912169089 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-06 00:00:00 the irrigation deficit is 2.0665587687175258 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-07 00:00:00 the irrigation deficit is 7.323604514030899 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-08 00:00:00 the irrigation deficit is 3.802594750744735 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-09 00:00:00 the irrigation deficit is 8.43907667104146 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-10 00:00:00 the irrigation deficit is 9.650122843249116 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-11 00:00:00 the irrigation deficit is 3.2687935937386925 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-12 00:00:00 the irrigation deficit is 5.903062736177864 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-13 00:00:00 the irrigation deficit is 7.543029609002533 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-14 00:00:00 the irrigation deficit is 3.201631819753956 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-15 00:00:00 the irrigation deficit is 5.011121306856824 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-16 00:00:00 the irrigation deficit is 5.870703258853238 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-17 00:00:00 the irrigation deficit is 7.013892184802839 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-18 00:00:00 the irrigation deficit is 9.269737920370588 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-19 00:00:00 the irrigation deficit is 2.871063614075215 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-20 00:00:00 the irrigation deficit is 3.6942066271892564 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-21 00:00:00 the irrigation deficit is 6.44928466274216 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-22 00:00:00 the irrigation deficit is 3.657750329284517 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-23 00:00:00 the irrigation deficit is 2.7704393379854935 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-24 00:00:00 the irrigation deficit is 7.929769732434362 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-25 00:00:00 the irrigation deficit is 7.178274611431389 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-26 00:00:00 the irrigation deficit is 6.22250025514116 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-27 00:00:00 the irrigation deficit is 8.345568612758983 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-28 00:00:00 the irrigation deficit is 8.218091601502614 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-29 00:00:00 the irrigation deficit is 7.09026828909875 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-30 00:00:00 the irrigation deficit is 7.594140530493199 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-07-31 00:00:00 the irrigation deficit is 1.4502101449267677 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-01 00:00:00 the irrigation deficit is 6.6736700941112375 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-02 00:00:00 the irrigation deficit is 10.7531538399165 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-03 00:00:00 the irrigation deficit is 10.827773250549694 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-04 00:00:00 the irrigation deficit is 5.733682678760237 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-05 00:00:00 the irrigation deficit is 9.241438726731747 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-06 00:00:00 the irrigation deficit is 10.713633138538626 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-07 00:00:00 the irrigation deficit is 8.737349689607491 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-08 00:00:00 the irrigation deficit is 9.049190567899466 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-09 00:00:00 the irrigation deficit is 9.01050967475608 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-10 00:00:00 the irrigation deficit is 5.207296122753629 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-11 00:00:00 the irrigation deficit is 6.846248226700098 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-12 00:00:00 the irrigation deficit is 4.439065692339973 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-13 00:00:00 the irrigation deficit is 8.159339435836506 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-14 00:00:00 the irrigation deficit is 3.7034735336667257 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-15 00:00:00 the irrigation deficit is 10.722699174925186 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-16 00:00:00 the irrigation deficit is 10.511999312218292 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-17 00:00:00 the irrigation deficit is 5.0920678173962255 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-18 00:00:00 the irrigation deficit is 6.225671772585407 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-19 00:00:00 the irrigation deficit is 5.570217389792578 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-20 00:00:00 the irrigation deficit is 9.243055166043554 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-21 00:00:00 the irrigation deficit is 10.025325639918268 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-22 00:00:00 the irrigation deficit is 12.14019245906489 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-23 00:00:00 the irrigation deficit is 2.261691204035529 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-24 00:00:00 the irrigation deficit is 7.783102083553196 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-25 00:00:00 the irrigation deficit is 11.098945545856797 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-26 00:00:00 the irrigation deficit is 10.622300353812955 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-27 00:00:00 the irrigation deficit is 7.15206065771984 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-28 00:00:00 the irrigation deficit is 12.28613072983711 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-29 00:00:00 the irrigation deficit is 11.408056302186498 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-30 00:00:00 the irrigation deficit is 12.23027271697 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-08-31 00:00:00 the irrigation deficit is 18.30295718373251 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-01 00:00:00 the irrigation deficit is 8.72420282836395 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-02 00:00:00 the irrigation deficit is 5.98904597108751 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-03 00:00:00 the irrigation deficit is 7.360867484172374 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-04 00:00:00 the irrigation deficit is 11.307871000493964 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-05 00:00:00 the irrigation deficit is 4.076553026919953 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-06 00:00:00 the irrigation deficit is 13.50848405958477 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-07 00:00:00 the irrigation deficit is 11.100162471596075 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-08 00:00:00 the irrigation deficit is 6.3786449225779815 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-09 00:00:00 the irrigation deficit is 8.255037426157887 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-10 00:00:00 the irrigation deficit is 11.544922519172871 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-11 00:00:00 the irrigation deficit is 10.405458993791859 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-12 00:00:00 the irrigation deficit is 7.3607726070200235 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-13 00:00:00 the irrigation deficit is 6.824124590179309 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-14 00:00:00 the irrigation deficit is 13.606360598161073 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-15 00:00:00 the irrigation deficit is 14.116619309567694 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-16 00:00:00 the irrigation deficit is 12.413108223153749 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-17 00:00:00 the irrigation deficit is 11.675802136937865 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-18 00:00:00 the irrigation deficit is 13.652354492017768 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-19 00:00:00 the irrigation deficit is 3.9020060622860946 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-20 00:00:00 the irrigation deficit is 13.699933408432699 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-21 00:00:00 the irrigation deficit is 9.907013442687697 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-22 00:00:00 the irrigation deficit is 9.53102229955337 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-23 00:00:00 the irrigation deficit is 16.372434535252477 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-24 00:00:00 the irrigation deficit is 8.041777811013255 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-25 00:00:00 the irrigation deficit is 7.261837970631255 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-26 00:00:00 the irrigation deficit is 11.204819680226922 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-27 00:00:00 the irrigation deficit is 9.560012967849481 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-28 00:00:00 the irrigation deficit is 13.834905820901955 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-29 00:00:00 the irrigation deficit is 8.415591392149878 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-09-30 00:00:00 the irrigation deficit is 5.801464672377719 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-01 00:00:00 the irrigation deficit is 6.280289015245627 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-02 00:00:00 the irrigation deficit is 7.08096308924436 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-03 00:00:00 the irrigation deficit is 9.94905266278884 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-04 00:00:00 the irrigation deficit is 11.567516013761985 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-05 00:00:00 the irrigation deficit is 7.443282411166935 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-06 00:00:00 the irrigation deficit is 1.4409349898669586 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-07 00:00:00 the irrigation deficit is 11.068073024446345 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-08 00:00:00 the irrigation deficit is 7.610343126237375 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-09 00:00:00 the irrigation deficit is 6.134147254385432 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-10 00:00:00 the irrigation deficit is 7.2775955331288245 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-11 00:00:00 the irrigation deficit is 10.554718941210242 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-12 00:00:00 the irrigation deficit is 6.947173555375569 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-13 00:00:00 the irrigation deficit is 10.368208244236865 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-14 00:00:00 the irrigation deficit is 10.855996984709082 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-15 00:00:00 the irrigation deficit is 8.497886090228384 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-16 00:00:00 the irrigation deficit is 9.832481769303072 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-17 00:00:00 the irrigation deficit is 13.380235380358926 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-18 00:00:00 the irrigation deficit is 6.537416584568533 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-19 00:00:00 the irrigation deficit is 7.6387217106633685 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-20 00:00:00 the irrigation deficit is 7.857632676562094 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-21 00:00:00 the irrigation deficit is 13.345284878455413 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-22 00:00:00 the irrigation deficit is 9.338222314552358 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-23 00:00:00 the irrigation deficit is 14.52785001011508 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-24 00:00:00 the irrigation deficit is 14.660649255744714 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-25 00:00:00 the irrigation deficit is 10.982885109344856 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-26 00:00:00 the irrigation deficit is 12.00086600506016 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-27 00:00:00 the irrigation deficit is 12.730915836243199 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-28 00:00:00 the irrigation deficit is 15.548521762065594 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-29 00:00:00 the irrigation deficit is 8.839275892000934 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-30 00:00:00 the irrigation deficit is 7.201145781933693 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-10-31 00:00:00 the irrigation deficit is 4.085426914273576 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-01 00:00:00 the irrigation deficit is 13.225945477280897 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-02 00:00:00 the irrigation deficit is 14.588876532436254 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-03 00:00:00 the irrigation deficit is 10.769173444708155 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-04 00:00:00 the irrigation deficit is 8.027457256299096 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-05 00:00:00 the irrigation deficit is 5.421114074109027 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-06 00:00:00 the irrigation deficit is 3.583083919146361 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-07 00:00:00 the irrigation deficit is 8.207403019331053 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-08 00:00:00 the irrigation deficit is 14.881660474848726 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-09 00:00:00 the irrigation deficit is 7.239871586914333 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-10 00:00:00 the irrigation deficit is 6.074235740722031 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-11 00:00:00 the irrigation deficit is 4.104229661972923 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-12 00:00:00 the irrigation deficit is 4.364397940968477 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-13 00:00:00 the irrigation deficit is 8.658855673249093 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-14 00:00:00 the irrigation deficit is 9.348601471912247 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-15 00:00:00 the irrigation deficit is 13.852426337535192 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-16 00:00:00 the irrigation deficit is 11.426081636487918 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-17 00:00:00 the irrigation deficit is 9.405687302663718 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-18 00:00:00 the irrigation deficit is 8.675792270096238 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-19 00:00:00 the irrigation deficit is 8.96869699197975 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-20 00:00:00 the irrigation deficit is 11.012404801136839 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-21 00:00:00 the irrigation deficit is 11.85971523729394 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-22 00:00:00 the irrigation deficit is 9.390260200550063 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-23 00:00:00 the irrigation deficit is 6.81222654763533 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-24 00:00:00 the irrigation deficit is 7.768535043787619 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-25 00:00:00 the irrigation deficit is 13.813188291305893 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-26 00:00:00 the irrigation deficit is 8.699931391312234 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-27 00:00:00 the irrigation deficit is 9.110287044652225 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-28 00:00:00 the irrigation deficit is 9.222291565472018 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-29 00:00:00 the irrigation deficit is 12.544029497443766 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-11-30 00:00:00 the irrigation deficit is 12.85636919183727 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-01 00:00:00 the irrigation deficit is 10.61131529438574 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-02 00:00:00 the irrigation deficit is 8.1298106324409 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-03 00:00:00 the irrigation deficit is 9.051080824221113 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-04 00:00:00 the irrigation deficit is 9.62793394517668 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-05 00:00:00 the irrigation deficit is 7.06277301742313 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-06 00:00:00 the irrigation deficit is 8.55179147334286 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-07 00:00:00 the irrigation deficit is 10.496781522062273 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-08 00:00:00 the irrigation deficit is 12.201276916044934 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-09 00:00:00 the irrigation deficit is 7.330235962565247 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-10 00:00:00 the irrigation deficit is 8.80511760606143 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-11 00:00:00 the irrigation deficit is 8.699870208234266 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-12 00:00:00 the irrigation deficit is 11.243633566537444 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-13 00:00:00 the irrigation deficit is 11.428224168568425 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-14 00:00:00 the irrigation deficit is 8.519514446875192 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-15 00:00:00 the irrigation deficit is 12.136561648631552 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-16 00:00:00 the irrigation deficit is 11.823051101933203 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-17 00:00:00 the irrigation deficit is 10.712885687326601 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-18 00:00:00 the irrigation deficit is 17.219324933654637 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-19 00:00:00 the irrigation deficit is 6.710620749458013 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-20 00:00:00 the irrigation deficit is 17.464174546716336 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-21 00:00:00 the irrigation deficit is 9.364259039558078 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-22 00:00:00 the irrigation deficit is 12.93342406250291 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-23 00:00:00 the irrigation deficit is 13.258588188050467 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-24 00:00:00 the irrigation deficit is 11.516750292264621 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-25 00:00:00 the irrigation deficit is 9.326831065067438 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-26 00:00:00 the irrigation deficit is 9.411600296568722 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-27 00:00:00 the irrigation deficit is 10.576479313192227 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-28 00:00:00 the irrigation deficit is 6.135745917973617 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-29 00:00:00 the irrigation deficit is 11.328497698971299 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-30 00:00:00 the irrigation deficit is 13.420171199002755 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2010-12-31 00:00:00 the irrigation deficit is 10.361276760235569 m3
# 1 panel(s) is not sufficient with variable speed operation, on 2011-01-01 00:00:00 the irrigation deficit is 14.795072569146944 m3
# ...
# 2 panel(s) is not sufficient with variable speed operation, on 2020-07-15 00:00:00 the irrigation deficit is 0.20417073184272283 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2020-07-22 00:00:00 the irrigation deficit is 2.197810568914047 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2020-11-03 00:00:00 the irrigation deficit is 0.6073453890979685 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2020-11-07 00:00:00 the irrigation deficit is 1.4757514637697806 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2020-11-08 00:00:00 the irrigation deficit is 2.1578922208273905 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-04-27 00:00:00 the irrigation deficit is 4.371738234525775 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-05-03 00:00:00 the irrigation deficit is 0.8926496887773325 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-05-04 00:00:00 the irrigation deficit is 3.687761749013635 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-05-22 00:00:00 the irrigation deficit is 1.6110431983051932 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-05-31 00:00:00 the irrigation deficit is 0.0859409413909269 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-07-12 00:00:00 the irrigation deficit is 2.715088956222857 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-07-18 00:00:00 the irrigation deficit is 1.0814452180988106 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-08-11 00:00:00 the irrigation deficit is 5.2898637861851 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-08-12 00:00:00 the irrigation deficit is 3.4460593542527826 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-10-12 00:00:00 the irrigation deficit is 2.3214801573730206 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2021-12-23 00:00:00 the irrigation deficit is 4.859917681678587 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-01-31 00:00:00 the irrigation deficit is 6.914263421998591 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-03-13 00:00:00 the irrigation deficit is 0.26914802948318695 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-03-28 00:00:00 the irrigation deficit is 5.700412676686218 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-04-13 00:00:00 the irrigation deficit is 0.27927336307625694 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 6.882988307672636 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-04-30 00:00:00 the irrigation deficit is 6.681632727477691 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-05-01 00:00:00 the irrigation deficit is 1.7145380502778762 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-06-14 00:00:00 the irrigation deficit is 1.5457432405471252 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-06-29 00:00:00 the irrigation deficit is 1.5355487433109474 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-06-30 00:00:00 the irrigation deficit is 1.287059429180779 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-07-03 00:00:00 the irrigation deficit is 4.840513825625755 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-07-18 00:00:00 the irrigation deficit is 2.5046945434221044 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-08-27 00:00:00 the irrigation deficit is 0.3105657112305664 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-09-02 00:00:00 the irrigation deficit is 2.358866041944367 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-09-13 00:00:00 the irrigation deficit is 2.4333658319460376 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-09-16 00:00:00 the irrigation deficit is 1.8720587476650792 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-09-19 00:00:00 the irrigation deficit is 1.6111834395903273 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-10-25 00:00:00 the irrigation deficit is 13.240502976405761 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-10-28 00:00:00 the irrigation deficit is 1.4427773471989145 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-12-07 00:00:00 the irrigation deficit is 2.1840206167193834 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2022-12-23 00:00:00 the irrigation deficit is 1.3454838547814845 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-02-15 00:00:00 the irrigation deficit is 0.6415247043401742 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-03-09 00:00:00 the irrigation deficit is 1.6221630836698075 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-03-10 00:00:00 the irrigation deficit is 1.3839570868204554 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-03-22 00:00:00 the irrigation deficit is 6.381199511854064 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-03-23 00:00:00 the irrigation deficit is 3.128821191967493 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-03-26 00:00:00 the irrigation deficit is 0.6495362963556204 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-04-05 00:00:00 the irrigation deficit is 3.247599387523959 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-04-06 00:00:00 the irrigation deficit is 4.512690021310014 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-05-08 00:00:00 the irrigation deficit is 4.158959627870761 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-05-17 00:00:00 the irrigation deficit is 2.907759677547368 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-05-19 00:00:00 the irrigation deficit is 0.5685994938900443 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-05-29 00:00:00 the irrigation deficit is 0.1645059458464786 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-05-30 00:00:00 the irrigation deficit is 3.300549275192605 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-06-18 00:00:00 the irrigation deficit is 2.3946214960675114 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-06-23 00:00:00 the irrigation deficit is 8.224066694211249 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-06-27 00:00:00 the irrigation deficit is 0.3486502725579719 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-06-28 00:00:00 the irrigation deficit is 1.1619813437133857 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-02 00:00:00 the irrigation deficit is 1.3604556316604999 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-05 00:00:00 the irrigation deficit is 1.0418539247641725 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-08 00:00:00 the irrigation deficit is 1.0422169968024448 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-11 00:00:00 the irrigation deficit is 1.1386310017117118 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-21 00:00:00 the irrigation deficit is 0.7646108453911005 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-25 00:00:00 the irrigation deficit is 15.145553691100307 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-28 00:00:00 the irrigation deficit is 4.441389990734329 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-07-31 00:00:00 the irrigation deficit is 7.40043755170116 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-02 00:00:00 the irrigation deficit is 5.0420175732021875 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-04 00:00:00 the irrigation deficit is 1.6736623947033493 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-07 00:00:00 the irrigation deficit is 1.8922243799814424 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 11.082078452215718 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-13 00:00:00 the irrigation deficit is 0.19983841867306396 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-15 00:00:00 the irrigation deficit is 0.3199636229128977 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-16 00:00:00 the irrigation deficit is 4.2890800751379 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-19 00:00:00 the irrigation deficit is 1.1035254649011499 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-08-20 00:00:00 the irrigation deficit is 0.46494877667902657 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-09-10 00:00:00 the irrigation deficit is 2.5856564914366125 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-09-26 00:00:00 the irrigation deficit is 6.653517850567535 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-09-27 00:00:00 the irrigation deficit is 3.9871848228914573 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-10-02 00:00:00 the irrigation deficit is 3.1362073338236804 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-10-08 00:00:00 the irrigation deficit is 2.7634305529130145 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-10-24 00:00:00 the irrigation deficit is 1.06572580057367 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-10-30 00:00:00 the irrigation deficit is 0.5422370828384366 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-11-03 00:00:00 the irrigation deficit is 0.7298589603714056 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-12-14 00:00:00 the irrigation deficit is 1.3597692641148171 m3
# 2 panel(s) is not sufficient with variable speed operation, on 2023-12-25 00:00:00 the irrigation deficit is 0.3488856351537972 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.329192682331783e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 3 panel(s) is not sufficient with variable speed operation, on 2010-01-03 00:00:00 the irrigation deficit is 0.814352292094453 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2010-01-26 00:00:00 the irrigation deficit is 0.1589927593227216 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 13.367521799705251 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 11.854382275944324 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2012-08-08 00:00:00 the irrigation deficit is 0.005893539830072569 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2012-08-25 00:00:00 the irrigation deficit is 0.02625010227899205 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2017-04-24 00:00:00 the irrigation deficit is 4.3922455985828694 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2018-07-10 00:00:00 the irrigation deficit is 3.9400987234780214 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2019-04-02 00:00:00 the irrigation deficit is 1.4989478319427931 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 2.9282220603451083 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2022-10-25 00:00:00 the irrigation deficit is 6.923099955440511 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2023-03-22 00:00:00 the irrigation deficit is 0.12786867917515465 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2023-07-25 00:00:00 the irrigation deficit is 7.210806083308647 m3
# 3 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 4.747132762166874 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '8.862127147904988e-05' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 4 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 10.098952019208408 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 7.7899150067946366 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2017-04-24 00:00:00 the irrigation deficit is 0.9658879469530941 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2022-04-17 00:00:00 the irrigation deficit is 0.26486114479082445 m3
# 4 panel(s) is not sufficient with variable speed operation, on 2023-08-12 00:00:00 the irrigation deficit is 0.44795136668697566 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00010457166410630913' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 5 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 6.777003015439828 m3
# 5 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 3.8943567414732208 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00012120678628741669' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 6 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 3.971614534770614 m3
# 6 panel(s) is not sufficient with variable speed operation, on 2010-03-06 00:00:00 the irrigation deficit is 0.7406403140378401 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00013860108148957854' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 7 panel(s) is not sufficient with variable speed operation, on 2010-03-05 00:00:00 the irrigation deficit is 1.9251614855325592 m3
# /var/folders/_q/cqfc7f7d18ng3r1chbk8y35h0000gn/T/ipykernel_17834/4102555792.py:34: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.00015684235027556425' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_solar_full.loc[hour, 'flow_rate'] = solution.root
# 8 panel(s) is sufficient with variable speed operation

# %% [markdown]
# ## Battery system optimization

# %%
# Lead acid battery characterisitics 

eta_charge = 0.95
eta_discharge = 0.95
SOC_min = 0.05 #5%
SOC_initial = 0.95 #100%
SOC_max = 0.95 #90%
deprciation = 0.001632 #depreciation per day for 8% per month
capacity = 1 #kWh

# %%
# Find minimum number of batteries required to cover all historical days 1 through 5 PV pannels 

for n_panels_battery in range(8, 11): #number of panels
    n_batteries = 0 #number of batteries in the string 
    flag = 0 #flag == 0 --> insufficient battery capacity found, flag == 1 --> sufficient battery capacity found

    #Calculate solar power output with n_pannels_battery
    loc = location.Location(18.541, -69.990, -4.00, 32.0) #CEBIVE
    solpos = loc.get_solarposition(weather_full.index)
    module_parameters = {'pdc0': 0.35, 'gamma_pdc': -0.004, 'b': 0.05} #350W pannel 
    temp_params = TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']

    array_full = pvsystem.Array(mount=pvsystem.FixedMount(20, 180),
                        module_parameters=module_parameters,
                        temperature_model_parameters=temp_params, modules_per_string=n_panels_battery)
    system_full = pvsystem.PVSystem(arrays=[array_full], inverter_parameters={'pdc0': 10, 'eta_inv_nom':0.95, 'strings_per_inverter':1 })
    mc_full = modelchain.ModelChain(system_full, loc, spectral_model='no_loss')
    _ = mc_full.run_model(weather_full)
    df_solar_battery = pd.DataFrame({'solar_power': mc_full.results.ac})
    

    #find minimum number of batteries needed to cover all historical days 
    while flag == 0:
        battery_capacity = capacity * n_batteries #kWh
        min_SOC = SOC_min * battery_capacity
        max_SOC = SOC_max * battery_capacity
        E_stored = [battery_capacity] #kWh, battery energy stored over time, initially full 
        day_flag = 0 
        for day, data in df_solar_battery.groupby(df_solar_battery.index.date):
            Q_day = 0 # m3 of water irrigated on day 
            Q_needed = df_daily_irrigation['2 ha'].loc[day.strftime('%Y-%m-%d')] #required irrigation in m3 
            power_day = df_solar_battery['solar_power'].loc[day.strftime('%Y-%m-%d')]
            
            for hour in data.index.hour:
                deficit = Q_needed - Q_day
                power = power_day.iloc[hour] #Power available to pump on that hour

                if deficit > 0: #Need to irrigate more water
                    if (power >= max_power) & (deficit > max_flow_rate * 3600): #Power is greater than max power so irrigate max possinle amount 
                        Q_day += max_flow_rate * 3600
                        E_storable = (power- max_power) * eta_charge #kWh
                    elif (power >= max_power) & (deficit <= max_flow_rate * 3600): #power is greater than max power but dont need to pump max amount
                        P_used = a * (deficit/3600)**3 + b * (deficit/3600)**2 + c * (deficit/3600) + d #power used to pump
                        Q_day += deficit
                        E_storable = (power- P_used) * eta_charge #kWh    
                    elif (power == 0): 
                        E_storable = 0 #no energy stored
                        Q_day += 0
                    elif (power < max_power): #power is less than max power, but still need to pump 
                        Q_possible = scipy.optimize.root_scalar(lambda x: root_pump_curve(a, b, c, d, power, x), x0=max_flow_rate)
                        E_storable = 0 #no energy stored
                        if Q_possible.root*3600 >= deficit:
                            Q_day += deficit
                        else:
                            Q_day += Q_possible.root * 3600
                    

                else: #dont need to irrigate more
                    E_storable =power*eta_charge 

                #Store energy
                if (E_storable + E_stored[-1]*(1-deprciation)) <= max_SOC:
                    E_stored.append(E_stored[-1]*(1-deprciation) + E_storable) #kWh
                else: #if more energy than battery can store, only store what battery can store
                    E_stored.append(max_SOC) #kWh
                
            
                
            if deficit > 0: #still need to irrigate more after all possible pumping hours have been exhausted
                
                #Use energy stored to pump --> Assume always pumping at max flow rate
                time_pump = (deficit / 3600)/ max_flow_rate 
                E_pump = (max_power * time_pump) / eta_discharge

                
                if (E_stored[-1] - E_pump) >= min_SOC: #if enough energy is stored to pump
                    E_stored.append(E_stored[-1]*(1-deprciation) - E_pump)
                else: #if not enough energy is stored to pump
                    #print(f'{n_batteries} batteries is not sufficient with {n_panels_battery} panels, on {day} the energy deficit is {E_pump - (E_stored[-1]- min_SOC)} kWh')
                    day_flag = 1 #flag == 1 --> n_panels_battery is not sufficient with battery operation over historical data

        if day_flag == 1: #after checking all days, if n_batteries is not sufficient with n_panels_battery
            n_batteries+=1
        else: #after checking all days, n_batteries is sufficient with n_panels_battery
            flag = 1 
            print(f'{n_batteries} Lithuim batteries is sufficient with {n_panels_battery} panels over historical data')
                
                    
        if n_batteries > 10: #safety check
            print(f'the required number of batteries is more than 10 for {n_panels_battery} panels')
            flag = 1
            
        
    #Takes 7m 55 with max 10 batteries
    #Takes 13m 4 with max 20 batteries
# Out:
# 1 Lithuim batteries is sufficient with 8 panels over historical data
# 1 Lithuim batteries is sufficient with 9 panels over historical data
# 0 Lithuim batteries is sufficient with 10 panels over historical data

# %% [markdown]
# # Tank Configuration

# %%
def system_curve (Q): 
    "based on a given flow rate (Q) in L/min return the Head (m) of the 2ha system with values for polyfit (DripNetwork.ipynb)"
    return 0.0014811456560022407*(Q**2) + 0.014248741431001915*Q 

print(f"the needed tank height is {system_curve(max_flow_rate* 60 *1000)} m for the 2 ha system")
# Out:
# the needed tank height is 20.639350454831224 m for the 2 ha system

# %%
def tank_pump_curve (Q):
    """based on a given flow rate (Q) in m3/s return the electrical Power (kW) of the pump for the tank configuration (H = 80.8) with variable speed op
        from PumpCurve.ipynb"""
    return 152054186.35597843*Q**3 + -172700.38396421436*Q**2 + 357.18109285749836*Q + -0.005691445084420055

tank_max_flow_rate = 0.003072606294153521 #m3/s
tank_max_power = tank_pump_curve(tank_max_flow_rate) 

def tank_system_curve_root(P, Q):
    return 152054186.35597843 * Q**3 - 172700.38396421436 * Q**2 + 357.18109285749836 * Q - 0.005691445084420055 - P
